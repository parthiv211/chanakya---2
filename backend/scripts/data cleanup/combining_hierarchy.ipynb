# %%
import pandas as pd

# %%
b = pd.read_csv('../../data/hierarchy/bala.csv')
p = pd.read_csv('../../data/hierarchy/pinky.csv')
r = pd.read_csv('../../data/hierarchy/riddhi.csv')
i = pd.read_csv('../../data/hierarchy/ishant.csv')

b['designer'] = 'Bala'
p['designer'] = 'Pinky'
r['designer'] = 'Ridhi'
i['designer'] = 'Ishant'

df = pd.concat([b, p, r, i])
df.reset_index(drop=True, inplace=True)
df
# Out:
#       gender vertical fabric_category                 brand   usage  \
# 0        Men  Apparel         Knitted  The Indian Garage Co  Casual
# 1        Men  Apparel         Knitted  The Indian Garage Co  Casual
# 2        Men  Apparel         Knitted  The Indian Garage Co  Casual
# 3        Men  Apparel         Knitted  The Indian Garage Co  Casual
# 4        Men  Apparel         Knitted  The Indian Garage Co  Casual
# ...      ...      ...             ...                   ...     ...
# 31945    Men  Apparel           Woven  The Indian Garage Co  Lounge
# 31946    Men  Apparel           Woven  The Indian Garage Co  Formal
# 31947    Men  Apparel           Woven  The Indian Garage Co  Formal
# 31948    Men  Apparel           Woven  The Indian Garage Co  Formal
# 31949    Men  Apparel           Woven  The Indian Garage Co  Formal
#
#              brick     product        sub_product target_audience  \
# 0          Topwear     T-Shirt  Crew Neck T-Shirt           Young
# ...

# %%
df['target_audience'] = df['target_audience'].replace('Young', 'Youth')

df['product'] = df['product'].replace('Chino', 'Chinos')
df['product'] = df['product'].replace('Jegging', 'Jeggings')
df['product'] = df['product'].replace('Jogger', 'Joggers')
df['product'] = df['product'].replace('Lounge Pant', 'Lounge Pants')
df['product'] = df['product'].replace('Trackpant', 'Trackpants')
df['product'] = df['product'].replace('Trouser', 'Trousers')

df['sub_product'] = df['sub_product'].replace('Basic Shirt', 'Regular Shirt')
df['sub_product'] = df['sub_product'].replace('Blazer And Pants Set','Blazer And Pants')
df['sub_product'] = df['sub_product'].replace('Blazer','Regular Blazer')
df['sub_product'] = df['sub_product'].replace('Cami Top And Pants Set','Cami Top And Pants')
df['sub_product'] = df['sub_product'].replace('Cami Top And Shorts Set','Cami Top And Shorts')
df['sub_product'] = df['sub_product'].replace('Cargo','Regular Cargo')
df['sub_product'] = df['sub_product'].replace('Chino', 'Regular Chinos')
df['sub_product'] = df['sub_product'].replace('Crew Neck Sweatshirt & Jogger', 'Crew Neck Sweatshirt And Joggers')
df['sub_product'] = df['sub_product'].replace('Crew Neck Sweatshirt & Shorts', 'Crew Neck Sweatshirt And Shorts')
df['sub_product'] = df['sub_product'].replace('Cuffed Jogger', 'Cuffed Joggers')
df['sub_product'] = df['sub_product'].replace('Denim Jegging', 'Denim Jeggings')
df['sub_product'] = df['sub_product'].replace('Denim Jogger', 'Denim Joggers')
df['sub_product'] = df['sub_product'].replace('Dungaree','Regular Dungaree')
df['sub_product'] = df['sub_product'].replace('Elasticated Denim Jegging', 'Elasticated Denim Jeggings')
df['sub_product'] = df['sub_product'].replace('Elasticated Trouser', 'Elasticated Trousers')
df['sub_product'] = df['sub_product'].replace('Five Pkt Jeans', 'Five Pocket Jeans')
df['sub_product'] = df['sub_product'].replace('Front Open High Neck Sweatshirt & Jogger', 'Front Open High Neck Sweatshirt And Joggers')
df['sub_product'] = df['sub_product'].replace('Front Open Hooded Sweatshirt & Jogger', 'Front Open Hooded Sweatshirt And Joggers')
df['sub_product'] = df['sub_product'].replace('Jeans','Regular Jeans')
df['sub_product'] = df['sub_product'].replace('Jegging', 'Regular Jeggings')
df['sub_product'] = df['sub_product'].replace('Joggers','Regular Joggers')
df['sub_product'] = df['sub_product'].replace('Jumpsuit','Regular Jumpsuit')
df['sub_product'] = df['sub_product'].replace('Knitted Jogger', 'Regular Joggers')
df['sub_product'] = df['sub_product'].replace('Knitted Shorts', 'Regular Shorts')
df['sub_product'] = df['sub_product'].replace('Knitted Trousers', 'Regular Trousers')
df['sub_product'] = df['sub_product'].replace('Kurta & Pyjama', 'Kurta And Pyjama')
df['sub_product'] = df['sub_product'].replace('Kurta','Regular Kurta')
df['sub_product'] = df['sub_product'].replace('Lounge Pant', 'Lounge Pants')
df['sub_product'] = df['sub_product'].replace('Lounge Shorts','Regular Lounge Shorts')
df['sub_product'] = df['sub_product'].replace('Nehru Jacket','Regular Nehru Jacket')
df['sub_product'] = df['sub_product'].replace('Overhead Crew Neck Sweatshirt & Jogger', 'Overhead Crew Neck Sweatshirt And Joggers')
df['sub_product'] = df['sub_product'].replace('Overhead Hooded Sweatshirt & Jogger', 'Overhead Hooded Sweatshirt And Joggers')
df['sub_product'] = df['sub_product'].replace('Overhead Hooded Sweatshirt & Shorts', 'Overhead Hooded Sweatshirt And Shorts')
df['sub_product'] = df['sub_product'].replace('Romper','Regular Romper')
df['sub_product'] = df['sub_product'].replace('Shirt & Boxer', 'Shirt And Boxers')
df['sub_product'] = df['sub_product'].replace('Shirt & Pant', 'Shirt And Pants')
df['sub_product'] = df['sub_product'].replace('Shirt And Shorts Set','Shirt And Shorts')
df['sub_product'] = df['sub_product'].replace('Shirt And Trousers Set','Shirt And Trousers')
df['sub_product'] = df['sub_product'].replace('Shirt','Regular Shirt')
df['sub_product'] = df['sub_product'].replace('Skorts','Regular Skorts')
df['sub_product'] = df['sub_product'].replace('Sweater','Regular Sweater')
df['sub_product'] = df['sub_product'].replace('Sweatshirt','Regular Sweatshirt')
df['sub_product'] = df['sub_product'].replace('T-shirt And Pants Set','T-Shirt And Pants')
df['sub_product'] = df['sub_product'].replace('T-shirt And Shorts Set','T-Shirt And Shorts')
df['sub_product'] = df['sub_product'].replace('T-shirt Dress','T-Shirt Dress')
df['sub_product'] = df['sub_product'].replace('Top And Pants Set','Top And Pants')
df['sub_product'] = df['sub_product'].replace('Top And Shorts Set','Top And Shorts')
df['sub_product'] = df['sub_product'].replace('Top And Skirt Set','Top And Skirt')
df['sub_product'] = df['sub_product'].replace('Trackpant', 'Regular Trackpants')
df['sub_product'] = df['sub_product'].replace('Windcheater','Regular Windcheater')
df['sub_product'] = df['sub_product'].replace('Woven Jacket', 'Regular Jacket')
df['sub_product'] = df['sub_product'].replace('Woven Jogger', 'Regular Joggers')
df['sub_product'] = df['sub_product'].replace('Woven Shorts', 'Regular Shorts')
df['sub_product'] = df['sub_product'].replace('Woven Trousers', 'Regular Trousers')

# add Fit
df['fit'] = df['fit'].replace('Baggy Fit', 'Baggy')
df['fit'] = df['fit'].replace('Bootcut Fit', 'Bootcut')
df['fit'] = df['fit'].replace('Boyfriend Fit', 'Boyfriend')
df['fit'] = df['fit'].replace('Cargo Fit', 'Cargo')
df['fit'] = df['fit'].replace('Carpenter Fit', 'Carpenter')
df['fit'] = df['fit'].replace('Carrot Fit', 'Carrot')
df['fit'] = df['fit'].replace('Dad Fit', 'Dad')
df['fit'] = df['fit'].replace('Flare Fit', 'Flare')
df['fit'] = df['fit'].replace('Flared', 'Flare')
df['fit'] = df['fit'].replace('Loose Fit', 'Loose')
df['fit'] = df['fit'].replace('Loose Mom Fit', 'Loose Mom')
df['fit'] = df['fit'].replace('Mom Fit', 'Mom')
df['fit'] = df['fit'].replace('Oversized Fit', 'Oversized')
df['fit'] = df['fit'].replace('Plus Baggy Fit', 'Plus Baggy')
df['fit'] = df['fit'].replace('Plus Bootcut Fit', 'Plus Bootcut')
df['fit'] = df['fit'].replace('Plus Boyfriend Fit', 'Plus Boyfriend')
# df['fit'] = df['fit'].replace('Plus Fit', 'Plus Fitted')
df['fit'] = df['fit'].replace('Plus Flare Fit', 'Plus Flare')
df['fit'] = df['fit'].replace('Plus Flared', 'Plus Flare')
df['fit'] = df['fit'].replace('Plus Loose Mom Fit', 'Plus Loose Mom')
df['fit'] = df['fit'].replace('Plus Mom Fit', 'Plus Mom')
df['fit'] = df['fit'].replace('Plus Skinny Fit', 'Plus Skinny')
df['fit'] = df['fit'].replace('Plus Slim Fit', 'Plus Slim')
df['fit'] = df['fit'].replace('Plus Slouchy Fit', 'Plus Slouchy')
df['fit'] = df['fit'].replace('Plus Straight Fit', 'Plus Straight')
df['fit'] = df['fit'].replace('Plus Super Skinny Fit', 'Plus Super Skinny')
df['fit'] = df['fit'].replace('Regular Fit', 'Regular')
df['fit'] = df['fit'].replace('Relaxed Fit', 'Relaxed')
df['fit'] = df['fit'].replace('Skinny Fit', 'Skinny')
df['fit'] = df['fit'].replace('Slim Fit', 'Slim')
df['fit'] = df['fit'].replace('Slouchy Fit', 'Slouchy')
df['fit'] = df['fit'].replace('Standard Tapered Fit', 'Standard Tapered')
df['fit'] = df['fit'].replace('Straight Fit', 'Straight')
df['fit'] = df['fit'].replace('Super Skinny Fit', 'Super Skinny')
df['fit'] = df['fit'].replace('Vintage Straight Fit', 'Vintage Straight')

# %%
df = df.drop(columns=['designer'])
df.drop_duplicates(inplace=True)

# dup_rows = df_ont.duplicated()
# df[dup_rows == True].to_csv('../../data/hierarchy/duplicates.csv', index=False)
# df[df['ontology']=='Men>Apparel>Woven>The Indian Garage Co>Casual>Topwear>Shirt>Denim Shirt>Youth>Slim Fit>S']

# %%
df
# Out:
#       gender vertical fabric_category                 brand   usage  \
# 0        Men  Apparel         Knitted  The Indian Garage Co  Casual
# 1        Men  Apparel         Knitted  The Indian Garage Co  Casual
# 2        Men  Apparel         Knitted  The Indian Garage Co  Casual
# 3        Men  Apparel         Knitted  The Indian Garage Co  Casual
# 28       Men  Apparel         Knitted  The Indian Garage Co  Lounge
# ...      ...      ...             ...                   ...     ...
# 31945    Men  Apparel           Woven  The Indian Garage Co  Lounge
# 31946    Men  Apparel           Woven  The Indian Garage Co  Formal
# 31947    Men  Apparel           Woven  The Indian Garage Co  Formal
# 31948    Men  Apparel           Woven  The Indian Garage Co  Formal
# 31949    Men  Apparel           Woven  The Indian Garage Co  Formal
#
#              brick     product        sub_product target_audience      fit  \
# ...

# %%
import pandas as pd
df = pd.read_csv('../../static/hierarchy.csv')

df['ontology']=df['gender']+'>'+df['vertical']+'>'+df['fabric_category']+'>'+df['brand']+'>'+df['usage']+'>'+df['brick']+'>'+df['product']+'>'+df['sub_product']+'>'+df['target_audience']+'>'+df['fit']+'>'+df['standard_size']
df.sort_values(by=['ontology'], inplace=True)
df = df.drop(columns=['ontology'])

df[df['brick']=='Topwear'].to_csv('../../data/hierarchy/topwear.csv', index=False)
df[df['brick']=='Bottomwear'].to_csv('../../data/hierarchy/bottomwear.csv', index=False)
df[df['brick']=='Coordinates'].to_csv('../../data/hierarchy/coordinates.csv', index=False)
# df.to_csv('../../data/hierarchy/hierarchycombined.csv', index=False)
